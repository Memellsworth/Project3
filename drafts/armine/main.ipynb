# %% [markdown]
# ## Analysis showing the IAH flight delays by the cause of delays for different airlines.

# %%
# Mute the Warnings
import shutup; shutup.please()

# Import Dependencies and Setup
import os
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.orm import Session
from zipfile import ZipFile
import matplotlib.pyplot as plt

# %%
# Files to Load
data_path = os.path.join("2022_delays.csv")
data_path
# Out:
# '2022_delays.csv'

# %%
#with ZipFile(os.path.join(data_path, "any.csv")) as delays_zip:
    #delays_zip.extractall(path=data_path)

# %%
# Read the file and store into Pandas DataFrames
delays_df = pd.read_csv(os.path.join(data_path))
delays_df.head()
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2022     12      AA  American Airlines Inc.     IAH
# 1  2022     12      AS    Alaska Airlines Inc.     IAH
# 2  2022     12      B6         JetBlue Airways     IAH
# 3  2022     12      DL    Delta Air Lines Inc.     IAH
# 4  2022     12      F9  Frontier Airlines Inc.     IAH
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Houston, TX: George Bush Intercontinental/Houston          451        137
# 1  Houston, TX: George Bush Intercontinental/Houston           54         19
# 2  Houston, TX: George Bush Intercontinental/Houston           85         30
# 3  Houston, TX: George Bush Intercontinental/Houston          643        161
# 4  Houston, TX: George Bush Intercontinental/Houston          101         42
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0       49.23        8.00  ...         3.89             47.92              5
# 1        7.24        4.04  ...         0.00              4.01              3
# 2       12.67        0.00  ...         0.00              2.78              0
# 3       81.56        3.09  ...         0.00             37.23             15
# 4       15.24        1.06  ...         0.00             11.24              4
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0             0       9372           3409            777       1109
# 1             0       1270            376            373        187
# 2             0       1693            873              0        619
# 3             1      11447           7065            392       1548
# 4             0       2566            832            234        780
#
#    security_delay  late_aircraft_delay
# 0             212                 3865
# 1               0                  334
# 2               0                  201
# 3               0                 2442
# 4               0                  720
#
# [5 rows x 21 columns]

# %%
delays_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 145 non-null    int64
#  1   month                145 non-null    int64
#  2   carrier              145 non-null    object
#  3   carrier_name         145 non-null    object
#  4   airport              145 non-null    object
#  5   airport_name         145 non-null    object
#  6   arr_flights          145 non-null    int64
#  7   arr_del15            145 non-null    int64
#  8   carrier_ct           145 non-null    float64
#  9   weather_ct           145 non-null    float64
#  10  nas_ct               145 non-null    float64
#  11  security_ct          145 non-null    float64
#  12  late_aircraft_ct     145 non-null    float64
#  13  arr_cancelled        145 non-null    int64
#  14  arr_diverted         145 non-null    int64
#  15  arr_delay            145 non-null    int64
#  16  carrier_delay        145 non-null    int64
#  17  weather_delay        145 non-null    int64
#  18  nas_delay            145 non-null    int64
#  19  security_delay       145 non-null    int64
#  20  late_aircraft_delay  145 non-null    int64
# dtypes: float64(5), int64(12), object(4)
# memory usage: 23.9+ KB

# %%
# Get the mean, max, min of the values.
delays_df.describe()
# Out:
#          year       month  arr_flights    arr_del15  carrier_ct  weather_ct  \
# count   145.0  145.000000   145.000000   145.000000  145.000000   145.00000
# mean   2022.0    6.475862   867.889655   147.448276   58.020207     6.51131
# std       0.0    3.464268  1308.551357   207.007613   76.908675     9.79568
# min    2022.0    1.000000     8.000000     2.000000    0.000000     0.00000
# 25%    2022.0    3.000000    65.000000    17.000000    6.680000     0.00000
# 50%    2022.0    6.000000   524.000000    96.000000   39.030000     2.21000
# 75%    2022.0    9.000000   800.000000   168.000000   62.760000     8.00000
# max    2022.0   12.000000  5478.000000  1226.000000  467.440000    43.00000
#
#            nas_ct  security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  \
# count  145.000000   145.000000        145.000000     145.000000    145.000000
# mean    37.947241     0.285862         44.683724      17.137931      2.565517
# std     61.229114     0.642142         71.756145      37.206746      5.241148
# min      0.000000     0.000000          0.000000       0.000000      0.000000
# 25%      4.310000     0.000000          3.300000       1.000000      0.000000
# 50%     11.820000     0.000000         26.000000       5.000000      1.000000
# 75%     36.730000     0.130000         50.440000      15.000000      2.000000
# max    328.660000     3.890000        426.710000     321.000000     45.000000
#
#           arr_delay  carrier_delay  weather_delay     nas_delay  \
# count    145.000000     145.000000     145.000000    145.000000
# mean   10743.248276    4682.013793     641.441379   1803.234483
# std    15579.981905    6468.969754    1035.431773   2858.877021
# min       63.000000       0.000000       0.000000      0.000000
# 25%      921.000000     376.000000       0.000000    211.000000
# 50%     5816.000000    2019.000000     202.000000    698.000000
# 75%    11504.000000    5298.000000     777.000000   1840.000000
# max    92350.000000   36649.000000    4992.000000  16545.000000
#
#        security_delay  late_aircraft_delay
# count      145.000000           145.000000
# mean        15.772414          3600.786207
# std         40.739134          6326.196307
# min          0.000000             0.000000
# 25%          0.000000           193.000000
# 50%          0.000000          1685.000000
# 75%          2.000000          3591.000000
# max        238.000000         41972.000000

# %%
# Load and Read the file, and store into Pandas DataFrames
data_path_1 = os.path.join("total_by_reason_2022.csv")
delays_df_1 = pd.read_csv(os.path.join(data_path_1))
delays_df_1
# Out:
#                            reason  total_delays
# 0                   Arrival Delay       1557771
# 1                   Weather Delay         93009
# 2  National Aviation System Delay        261469
# 3                  Security Delay          2287
# 4             Late Aircraft Delay        522114

# %%
# Creating a pie chart
sizes = [1557771, 93009, 261469, 2287, 522114]
explode = (0.05, 0.04, 0.04, 0.04, 0.05)
plt.pie(delays_df_1["total_delays"], explode=explode, autopct="%1.1f%%", labels = delays_df_1["reason"])
plt.title("Total Delays by Reasons")
# Out:
# Text(0.5, 1.0, 'Total Delays by Reasons')

# %% [markdown]
# ### The Pie Chart above shows the flight delays by the cause of the delays. And we can see that the highest percentage of the delays has the Arrival Delay with 63.9% from the total delays. The lowest percentage is for the Security Delay with 0.1% from the total.

# %%
delays_df.head()
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2022     12      AA  American Airlines Inc.     IAH
# 1  2022     12      AS    Alaska Airlines Inc.     IAH
# 2  2022     12      B6         JetBlue Airways     IAH
# 3  2022     12      DL    Delta Air Lines Inc.     IAH
# 4  2022     12      F9  Frontier Airlines Inc.     IAH
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Houston, TX: George Bush Intercontinental/Houston          451        137
# 1  Houston, TX: George Bush Intercontinental/Houston           54         19
# 2  Houston, TX: George Bush Intercontinental/Houston           85         30
# 3  Houston, TX: George Bush Intercontinental/Houston          643        161
# 4  Houston, TX: George Bush Intercontinental/Houston          101         42
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0       49.23        8.00  ...         3.89             47.92              5
# 1        7.24        4.04  ...         0.00              4.01              3
# 2       12.67        0.00  ...         0.00              2.78              0
# 3       81.56        3.09  ...         0.00             37.23             15
# 4       15.24        1.06  ...         0.00             11.24              4
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0             0       9372           3409            777       1109
# 1             0       1270            376            373        187
# 2             0       1693            873              0        619
# 3             1      11447           7065            392       1548
# 4             0       2566            832            234        780
#
#    security_delay  late_aircraft_delay
# 0             212                 3865
# 1               0                  334
# 2               0                  201
# 3               0                 2442
# 4               0                  720
#
# [5 rows x 21 columns]

# %%
# Filtering the DataFrame by columns needed, grouping by the carrier_name and getting the agg numbers. 
delays_df_cleaned = delays_df[["carrier_delay", "arr_delay", "carrier_name", "weather_delay", "nas_delay", "security_delay", "late_aircraft_delay"]].groupby("carrier_name").agg(["mean"])
delays_df_cleaned.columns = [f"{column[0]}_{column[1]}" if type(column) is tuple else column for column in delays_df_cleaned.columns]
delays_df_cleaned
# Out:
#                         carrier_delay_mean  arr_delay_mean  \
# carrier_name
# Alaska Airlines Inc.            206.416667      456.750000
# American Airlines Inc.         3081.250000     8222.000000
# Delta Air Lines Inc.           4536.750000     7928.000000
# Envoy Air                        97.916667      533.250000
# Frontier Airlines Inc.          819.000000     1893.500000
# JetBlue Airways                 770.166667     1238.250000
# Mesa Airlines Inc.            11135.833333    23150.416667
# PSA Airlines Inc.                 0.000000       63.000000
# Republic Airline                217.916667      767.416667
# SkyWest Airlines Inc.         10476.166667    17431.583333
# Southwest Airlines Co.         2100.916667     5979.833333
# Spirit Air Lines               3271.500000     9632.916667
# United Air Lines Inc.         19860.500000    52575.083333
#
#                         weather_delay_mean  nas_delay_mean  \
# carrier_name
# Alaska Airlines Inc.             44.833333      119.416667
# American Airlines Inc.          503.416667     1287.833333
# Delta Air Lines Inc.            313.583333     1369.166667
# Envoy Air                        63.750000      209.416667
# Frontier Airlines Inc.           33.000000      421.250000
# JetBlue Airways                  37.916667      296.833333
# Mesa Airlines Inc.             2569.083333     4523.750000
# PSA Airlines Inc.                 0.000000       61.000000
# Republic Airline                 75.916667      227.083333
# SkyWest Airlines Inc.          1477.000000      461.000000
# Southwest Airlines Co.          190.166667      845.500000
# Spirit Air Lines                337.666667     3151.083333
# United Air Lines Inc.          2104.416667     8871.666667
#
#                         security_delay_mean  late_aircraft_delay_mean
# carrier_name
# Alaska Airlines Inc.               0.000000                 86.083333
# American Airlines Inc.            20.333333               3329.166667
# Delta Air Lines Inc.              13.583333               1694.916667
# Envoy Air                          0.000000                162.166667
# Frontier Airlines Inc.             0.000000                620.250000
# JetBlue Airways                    3.250000                130.083333
# Mesa Airlines Inc.                37.166667               4884.583333
# PSA Airlines Inc.                  2.000000                  0.000000
# Republic Airline                   6.250000                240.250000
# SkyWest Airlines Inc.              7.333333               5010.083333
# Southwest Airlines Co.            22.166667               2821.083333
# Spirit Air Lines                  51.666667               2821.000000
# United Air Lines Inc.             28.666667              21709.833333

# %%
# Creating a Line Chart for the mean by carrier_name

delays_df_cleaned.plot(figsize=(20, 12))

plt.xticks(rotation="vertical")
plt.xlabel("Carrier Name")
plt.ylabel("Average Yearly Delays in Minutes")
plt.title("Average Yearly Delays")
# Out:
# Text(0.5, 1.0, 'Average Yearly Delays')

# %%
delays_df_cleaned_1 = delays_df[["month", "weather_delay"]].groupby("month").agg(["max", "mean"])
delays_df_cleaned_1.columns = [f"{column[0]}_{column[1]}" if type(column) is tuple else column for column in delays_df_cleaned_1.columns]
delays_df_cleaned_1
# Out:
#        weather_delay_max  weather_delay_mean
# month
# 1                   2950          654.833333
# 2                   4748          749.416667
# 3                   4201          641.230769
# 4                   2465          531.833333
# 5                   3500          665.250000
# 6                   3736          896.250000
# 7                   2779          656.250000
# 8                   4992         1096.166667
# 9                   2840          559.166667
# 10                   636          150.083333
# 11                  1537          387.000000
# 12                  2497          709.833333

# %%
delays_df_cleaned_1.plot(figsize=(20, 6))

plt.xticks(rotation="vertical")
plt.xlabel("Month")
plt.ylabel("Max and Average Delays")
plt.title("Max and Average")
# Out:
# Text(0.5, 1.0, 'Max and Average')

# %%
# Import Dependencies and Setup
import sqlalchemy
from sqlalchemy import column
from sqlalchemy.dialects.postgresql import insert
from sqlalchemy import table, column
from sqlalchemy.dialects import postgresql
from sqlalchemy.orm import aliased
from sqlalchemy import create_engine

# %%
from sqlalchemy import URL

url_object = URL.create(
    "postgresql",
    username="chernika81",
    password="kx@jj5/g",  # plain (unescaped) text
    host="pghost10",
    database="Delays",
)

# %%
#engine = create_engine(url_object)

# %%
engine = sqlalchemy.create_engine("postgresql://chernika81:Arm1108811!@localhost10/Delays")

# %%
connection = engine.connect()

# %%
delays_df.to_sql("delays", connection, if_exists="replace")
