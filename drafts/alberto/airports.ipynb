# %%
import requests
import pandas as pd

# %%
airports = pd.read_csv("../rawdata/clean/full_detail_airports.csv")

# %%
airports.head(10)
# Out:
#    Unnamed: 0 local_code       id ident            type  \
# 0           0        ABI   3357.0  KABI  medium_airport
# 1           1        ABQ  16091.0  KABQ  medium_airport
# 2           2        ACY   3363.0  KACY  medium_airport
# 3           3        AEX   3365.0  KAEX  medium_airport
# 4           4        AGS   3368.0  KAGS  medium_airport
# 5           5        AMA   3377.0  KAMA  medium_airport
# 6           6        ANC   5388.0  PANC   large_airport
# 7           7        ASE  19308.0  KASE  medium_airport
# 8           8        ATL   3384.0  KATL   large_airport
# 9           9        AUS   3386.0  KAUS   large_airport
#
#                                                name  latitude_deg  \
# 0                          Abilene Regional Airport     32.411301
# 1                 Albuquerque International Sunport     35.040199
# 2               Atlantic City International Airport     39.457600
# 3                  Alexandria International Airport     31.327400
# ...

# %%
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame
from shapely.geometry import Point

# %%
geometry = [Point(xy) for xy in zip(airports['longitude_deg'], airports['latitude_deg'])]
gdf = GeoDataFrame(airports, geometry=geometry)

# %%
gdf.to_file("airports_key.json", driver="GeoJSON")
# Out:
# d:\RDA\envs\dev00\lib\site-packages\geopandas\io\file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
