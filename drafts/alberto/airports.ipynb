# %%
import requests
import pandas as pd

# %%
airports = pd.read_csv("../rawdata/clean/airport_key.csv")

# %%
airports
# Out:
#     local_code
# 0          ABI
# 1          ABQ
# 2          ACY
# 3          AEX
# 4          AGS
# ..         ...
# 138        TYR
# 139        TYS
# 140        VCT
# 141        VPS
# 142        XNA
#
# [143 rows x 1 columns]

# %%
full_airports = pd.read_csv("../rawdata/clean/us-airports.csv")

# %%
merged_df = airports.merge(full_airports, on='local_code', how='left')

# %%
merged_df
# Out:
#     local_code       id ident            type  \
# 0          ABI   3357.0  KABI  medium_airport
# 1          ABQ  16091.0  KABQ  medium_airport
# 2          ACY   3363.0  KACY  medium_airport
# 3          AEX   3365.0  KAEX  medium_airport
# 4          AGS   3368.0  KAGS  medium_airport
# ..         ...      ...   ...             ...
# 138        TYR   3937.0  KTYR  medium_airport
# 139        TYS   3938.0  KTYS  medium_airport
# 140        VCT   3945.0  KVCT  medium_airport
# 141        VPS   3948.0  KVPS  medium_airport
# 142        XNA  21410.0  KXNA  medium_airport
#
#                                     name  latitude_deg  longitude_deg  \
# 0               Abilene Regional Airport     32.411301     -99.681900
# 1      Albuquerque International Sunport     35.040199    -106.609001
# 2    Atlantic City International Airport     39.457600     -74.577202
# 3       Alexandria International Airport     31.327400     -92.549797
# ...

# %%
merged_df.to_csv("full_detail_airports.csv")
